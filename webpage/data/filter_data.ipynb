# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0      country  id continent  year  happiness_rating  \
# 0           0  Afghanistan  AF      Asia  2011             3.832
# 1           1  Afghanistan  AF      Asia  2012             3.783
# 2           2  Afghanistan  AF      Asia  2013             3.572
# 3           3  Afghanistan  AF      Asia  2014             3.131
# 4           4  Afghanistan  AF      Asia  2015             3.983
#
#    gdp_per_capita  social_support  life_expectancy  freedom  generosity  \
# 0           7.620           0.521            51.92    0.496       0.162
# 1           7.705           0.521            52.24    0.531       0.236
# 2           7.725           0.484            52.56    0.578       0.061
# 3           7.718           0.526            52.88    0.509       0.104
# 4           7.702           0.529            53.20    0.389       0.080
#
#    corruption
# 0       0.731
# 1       0.776
# 2       0.823
# 3       0.871
# 4       0.881

# %%
data = data.drop(columns=['Unnamed: 0', 'id', 'continent', ])

# %%
data = data.round({'happiness_rating': 3, 'gdp_per_capita': 3, 'social_support': 3, 'life_expectancy': 2, 'freedom': 3, 'generosity': 3, 'corruption': 3})

# %%
data.head()
# Out:
#        country  year  happiness_rating  gdp_per_capita  social_support  \
# 0  Afghanistan  2011             3.832           7.620           0.521
# 1  Afghanistan  2012             3.783           7.705           0.521
# 2  Afghanistan  2013             3.572           7.725           0.484
# 3  Afghanistan  2014             3.131           7.718           0.526
# 4  Afghanistan  2015             3.983           7.702           0.529
#
#    life_expectancy  freedom  generosity  corruption
# 0            51.92    0.496       0.162       0.731
# 1            52.24    0.531       0.236       0.776
# 2            52.56    0.578       0.061       0.823
# 3            52.88    0.509       0.104       0.871
# 4            53.20    0.389       0.080       0.881

# %%
data.to_csv('data_filtered.csv', index=False)
